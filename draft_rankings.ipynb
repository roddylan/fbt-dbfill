# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
from io import StringIO
import json

teams = [
  "ARI",
  "ATL",
  "BAL",
  "BUF",
  "CAR",
  "CHI",
  "CIN",
  "CLE",
  "DAL",
  "DEN",
  "DET",
  "GB",
  "HOU",
  "IND",
  "JAX",
  "KC",
  "LV",
  "LAC",
  "LAR",
  "MIA",
  "MIN",
  "NE",
  "NO",
  "NYG",
  "NYJ",
  "PHI",
  "PIT",
  "SF",
  "SEA",
  "TB",
  "TEN",
  "WAS",
]

pos = [
  "qb",
  "rb",
  "wr",
  "te",
  "k",
  "dst",
  # ----- DEFENSIVE POSITIONS -----
  # "idp",
  # "dl",
  # "lb",
  # "db",
]

url = "postgresql://user:pass@localhost:5432/fbt"

# %%
def pfr_player_url(player_id: str, year: int = 2024) -> str:
  assert(len(player_id) > 0)
  return f"https://www.pro-football-reference.com/players/{player_id[0].upper()}/{player_id}/gamelog/{year}"

def pfr_team_url(team: str, year: int = 2024) -> str:
  return f"https://www.pro-football-reference.com/teams/{team}/{year}/gamelog"

def team_fantasy_url(team: str, year: int = 2024, week_from: int = 1, week_to: int = 18):
  assert(year > 2018)
  assert(week_from >= 1 and week_from <= week_to)
  assert(week_to >= week_from and week_to <= 18)
  return f"https://fantasydata.com/nfl/fantasy-football-leaders?scope=game&sp={year}_REG&week_from={week_from}&week_to={week_to}&position=dst&team={team}&scoring=fpts_ppr&order_by=team&sort_dir=asc"

def fantasy_url(team: str, pos: str, year: int = 2024, week_from: int = 1, week_to: int = 18):
  assert(year > 2018)
  assert(week_from >= 1 and week_from <= week_to)
  assert(week_to >= week_from and week_to <= 18)
  return f"https://fantasydata.com/nfl/fantasy-football-leaders?scope=game&sp={year}_REG&week_from={week_from}&week_to={week_to}&position={pos}&team={team}&scoring=fpts_ppr&order_by=team&sort_dir=asc"


def ffb_calc(year: int = 2024):
  return f"https://fantasyfootballcalculator.com/api/v1/adp/ppr?teams=12&year={year}&position=all"

# %%
names_to_pid = {}
pid_to_players = {}

with open("name_to_id.json", 'r') as f:
  names_to_pid=json.loads(f.read())

with open("id_to_player.json", 'r') as f:
  pid_to_players=json.loads(f.read())

# %%
draft = {}
d = json.loads(requests.get(ffb_calc(year=2024)).text)
df = pd.DataFrame.from_dict(d['players'])
# Out:
#      player_id                 name position team    adp adp_formatted  \
# 0         2434  Christian McCaffrey       RB   SF    1.4          1.01
# 1         5503          Breece Hall       RB  NYJ    2.2          1.02
# 2         2390          Tyreek Hill       WR  MIA    2.6          1.03
# 3         4869          CeeDee Lamb       WR  DAL    3.7          1.04
# 4         5670       Bijan Robinson       RB  ATL    4.9          1.05
# ..         ...                  ...      ...  ...    ...           ...
# 200       6276     Tyrone Tracy Jr.       RB  NYG  174.0         22.06
# 201       1319  New Orleans Defense      DEF   NO  174.7         22.07
# 202       1960        Greg Zuerlein       PK  NYJ  174.9         22.07
# 203       6253               Bo Nix       QB  DEN  177.5         23.02
# 204       1390          Matt Prater       PK  ARI  193.5         25.01
#
#      times_drafted  high  low  stdev  bye
# 0              181     1    5    0.7   14
# 1               68     1    5    0.9    9
# 2              144     1    6    0.9   12
# 3              321     1    6    1.3   10
# 4              281     1    9    1.3    5
# ..             ...   ...  ...    ...  ...
# 200             16   150  201   15.7   14
# 201             10   145  199   13.1   11
# 202             25   137  203   20.2    9
# 203             15   126  208   21.3   12
# 204             17   169  206   13.0    8
#
# [205 rows x 11 columns]
